# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("train.csv")

# %%
data.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0  462809    Male           No   22        No     Healthcare              1.0
# 1  462643  Female          Yes   38       Yes       Engineer              NaN
# 2  466315  Female          Yes   67       Yes       Engineer              1.0
# 3  461735    Male          Yes   67       Yes         Lawyer              0.0
# 4  462669  Female          Yes   40       Yes  Entertainment              NaN
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          4.0  Cat_4            D
# 1        Average          3.0  Cat_4            A
# 2            Low          1.0  Cat_6            B
# 3           High          2.0  Cat_6            B
# 4           High          6.0  Cat_6            A

# %%
data["Segmentation"].unique()
# Out:
# array(['D', 'A', 'B', 'C'], dtype=object)

# %% [markdown]
# ## feature Enineereing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
data["Gender"] = encoder.fit_transform(data["Gender"])
data["Ever_Married"] = encoder.fit_transform(data["Ever_Married"])
data["Graduated"] = encoder.fit_transform(data["Graduated"])
data["Profession"] = encoder.fit_transform(data["Profession"])
data["Spending_Score"] = encoder.fit_transform(data["Spending_Score"])
data["Var_1"] = encoder.fit_transform(data["Var_1"])
data["Segmentation"] = encoder.fit_transform(data["Segmentation"])

# %%
data.head()
# Out:
#        ID  Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0  462809       1             0   22          0           5              1.0
# 1  462643       0             1   38          1           2              NaN
# 2  466315       0             1   67          1           2              1.0
# 3  461735       1             1   67          1           7              0.0
# 4  462669       0             1   40          1           3              NaN
#
#    Spending_Score  Family_Size  Var_1  Segmentation
# 0               2          4.0      3             3
# 1               0          3.0      3             0
# 2               2          1.0      5             1
# 3               1          2.0      5             1
# 4               1          6.0      5             0

# %%
data.isnull().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married         0
# Age                  0
# Graduated            0
# Profession           0
# Work_Experience    829
# Spending_Score       0
# Family_Size        335
# Var_1                0
# Segmentation         0
# dtype: int64

# %%
data["Work_Experience"].count()
# Out:
# 7239

# %%
data.corr()*100
# Out:
#                          ID      Gender  Ever_Married         Age   Graduated  \
# ID               100.000000    0.615538      2.580309   -0.505538   -0.374068
# Gender             0.615538  100.000000      9.911458    3.021587   -3.043579
# Ever_Married       2.580309    9.911458    100.000000   51.974573   16.459420
# Age               -0.505538    3.021587     51.974573  100.000000   22.928260
# Graduated         -0.374068   -3.043579     16.459420   22.928260  100.000000
# Profession        -0.472030    2.176235    -11.223657    3.638906  -27.006666
# Work_Experience   -3.068802   -5.987837     -8.748905  -19.078931    3.502112
# Spending_Score    -1.894904   -5.426050    -59.522632  -26.954394  -14.763196
# Family_Size        1.180090    5.591058     -6.854696  -28.051700  -21.821722
# Var_1             -0.385427    2.688174      5.751595   16.496739   10.234925
# Segmentation      -0.910424    2.640347    -19.814709  -24.355230  -17.494862
#
#                  Profession  Work_Experience  Spending_Score  Family_Size  \
# ID                -0.472030        -3.068802       -1.894904     1.180090
# Gender             2.176235        -5.987837       -5.426050     5.591058
# Ever_Married     -11.223657        -8.748905      -59.522632    -6.854696
# Age                3.638906       -19.078931      -26.954394   -28.051700
# Graduated        -27.006666         3.502112      -14.763196   -21.821722
# Profession       100.000000        -2.325295       22.088946     8.084582
# Work_Experience   -2.325295       100.000000        4.829157    -6.323385
# Spending_Score    22.088946         4.829157      100.000000   -11.453136
# Family_Size        8.084582        -6.323385      -11.453136   100.000000
# Var_1             -4.330175         2.260790       -3.134084   -14.467731
# Segmentation      20.241865         1.299265       10.057174    19.621279
#
#                       Var_1  Segmentation
# ID                -0.385427     -0.910424
# Gender             2.688174      2.640347
# Ever_Married       5.751595    -19.814709
# Age               16.496739    -24.355230
# Graduated         10.234925    -17.494862
# Profession        -4.330175     20.241865
# Work_Experience    2.260790      1.299265
# Spending_Score    -3.134084     10.057174
# Family_Size      -14.467731     19.621279
# Var_1            100.000000     -1.723297
# Segmentation      -1.723297    100.000000

# %%
data = data.drop(columns = ["ID", "Gender", "Ever_Married", "Age", "Graduated", "Var_1"], axis = 1)

# %%
data["Family_Size"] = data["Family_Size"].fillna(method = "bfill")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24540\585093989.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data["Family_Size"] = data["Family_Size"].fillna(method = "bfill")

# %%
data["Work_Experience"] = data["Work_Experience"].fillna(method = "ffill")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24540\666724675.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data["Work_Experience"] = data["Work_Experience"].fillna(method = "ffill")

# %%
data.head()
# Out:
#    Profession  Work_Experience  Spending_Score  Family_Size  Segmentation
# 0           5              1.0               2          4.0             3
# 1           2              1.0               0          3.0             0
# 2           2              1.0               2          1.0             1
# 3           7              0.0               1          2.0             1
# 4           3              0.0               1          6.0             0

# %%
x = data.iloc[:,:-1]
y = data["Segmentation"]

# %%
x.head()
# Out:
#    Profession  Work_Experience  Spending_Score  Family_Size
# 0           5              1.0               2          4.0
# 1           2              1.0               0          3.0
# 2           2              1.0               2          1.0
# 3           7              0.0               1          2.0
# 4           3              0.0               1          6.0

# %%
y.head()
# Out:
# 0    3
# 1    0
# 2    1
# 3    1
# 4    0
# Name: Segmentation, dtype: int32

# %%
correlation = data.corr()

# %%
sns.heatmap(correlation, annot = True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.71194485, -0.47845553,  0.75339607,  0.74524561],
#        [-0.33100537, -0.77134674,  0.75339607,  1.3988419 ],
#        [-0.33100537, -0.47845553,  0.75339607, -1.21554328],
#        ...,
#        [ 1.57369206,  0.40021809,  0.75339607, -1.21554328],
#        [-1.09288433, -0.77134674,  0.75339607,  1.3988419 ],
#        [ 0.81181309, -0.47845553,  0.75339607,  4.01322709]])

# %%
X_test = scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[ 0.01866829, -0.16894756,  0.758806  ,  0.12036462],
#        [ 0.01866829, -0.772893  , -1.57176086, -0.53373804],
#        [ 0.77193389,  0.43499788,  0.758806  ,  1.42856993],
#        ...,
#        [-0.35796451, -0.772893  , -1.57176086, -0.53373804],
#        [ 0.77193389,  1.64288875,  0.758806  , -1.1878407 ],
#        [ 0.01866829, -0.47092028,  0.758806  ,  0.77446727]])

# %%
X_train.shape
# Out:
# (6454, 4)

# %%
y_train.shape
# Out:
# (6454,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(random_state = 42)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.4485749690210657
