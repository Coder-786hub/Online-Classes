# %%
import matplotlib.pyplot as plt
import matplotlib.image as mtshow
import pandas as pd

# %%
data1 = data1={"Country":[20,30,50,70,12,34,43,43,23,45,67,98],
"Population":[90,80,100,70,80,90,105,98,99,78,97,96]}
data = pd.DataFrame(data1)
data.to_csv("Data.csv", index = False)

# %%
data = pd.read_csv("Data.csv", )
data
# Out:
#     Country  Population
# 0        20          90
# 1        30          80
# 2        50         100
# 3        70          70
# 4        12          80
# 5        34          90
# 6        43         105
# 7        43          98
# 8        23          99
# 9        45          78
# 10       67          97
# 11       98          96

# %%
plt.plot(data)
plt.show()

# %%
plt.bar(data["Country"], data["Population"])
plt.show()

# %%
from PIL import Image

# %%
image = Image.open("th (1).jpg")
plt.imshow(image)
plt.show()

# %%
image = mtshow.imread("th (3).jpg")
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
image = mtshow.imread("th (3).jpg")
plt.matshow(image)
plt.axis("on")
plt.show()
